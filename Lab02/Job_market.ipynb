# %%
# Nguyen Huu Quyen - 19522113
# Lab 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import re

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#  Load the data using Pandas.
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Data_Mining/Thuc_hanh/job-market.csv')
df.head()

# %%
# Visualize top 10 first rows

# %%
df.head(10)

# %%
# display information about the dataframe
print(df.info())

# %%
# display summary statistics of the numerical columns
print(df.describe())

# %%
df.dtypes

# %%
  # convert Date to datetime object
df['Date'] = pd.to_datetime(df['Date'])

# %%
 # convert Id to integer and handle NaN values
df['Id'] = df['Id'].astype('Int64')

# %%
 # convert LowestSalary to integer and handle NaN values
df['LowestSalary'] = df['LowestSalary'].astype('Int64')

# %%
# convert HighestSalary to integer and handle NaN values

df['HighestSalary'] = df['HighestSalary'].astype('Int64')

# %%
# replace NaN values with empty strings in Area, FullDescription, and JobType columns
# df['Area'] = df['Area'].fillna('')
# df['FullDescription'] = df['FullDescription'].fillna('')
# df['JobType'] = df['JobType'].fillna('')

# %%
df.head(10)

# %%
df.dtypes

# %%
# Check and clean the data.

# %%
# check for any missing or null values
print(df.isnull().sum())

# %%
# drop any rows with missing or null values
df = df.dropna()

# %%
# check for any duplicate rows
print(df.duplicated().sum())

# %%
# drop any duplicate rows
df = df.drop_duplicates()

# %%
df.head(10)
